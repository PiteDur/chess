# %%
import numpy as np
from chess import board

# %%
b = board("black")
ar_board = b.create_board()

# %%
b.display_board(ar_board)
# Out:
# {'a8': np.str_('r'),
#  'b8': np.str_('n'),
#  'c8': np.str_('b'),
#  'd8': np.str_('q'),
#  'e8': np.str_('k'),
#  'f8': np.str_('b'),
#  'g8': np.str_('n'),
#  'h8': np.str_('r'),
#  'a7': np.str_('p'),
#  'b7': np.str_('p'),
#  'c7': np.str_('p'),
#  'd7': np.str_('p'),
#  'e7': np.str_('p'),
#  'f7': np.str_('p'),
#  'g7': np.str_('p'),
#  'h7': np.str_('p'),
#  'a6': np.str_(' '),
#  'b6': np.str_(' '),
#  'c6': np.str_(' '),
#  'd6': np.str_(' '),
#  'e6': np.str_(' '),
#  'f6': np.str_(' '),
#  'g6': np.str_(' '),
#  'h6': np.str_(' '),
#  'a5': np.str_(' '),
#  'b5': np.str_(' '),
#  'c5': np.str_(' '),
#  'd5': np.str_(' '),
#  'e5': np.str_(' '),
#  'f5': np.str_(' '),
#  'g5': np.str_(' '),
#  'h5': np.str_(' '),
#  'a4': np.str_(' '),
#  'b4': np.str_(' '),
#  'c4': np.str_(' '),
#  'd4': np.str_(' '),
#  'e4': np.str_(' '),
#  'f4': np.str_(' '),
#  'g4': np.str_(' '),
#  'h4': np.str_(' '),
#  'a3': np.str_(' '),
#  'b3': np.str_(' '),
#  'c3': np.str_(' '),
# ...

# %%
b.display_positions(ar_board)
# Out:
# {np.str_('r'): ['a8', 'h8'],
#  np.str_('n'): ['b8', 'g8'],
#  np.str_('b'): ['c8', 'f8'],
#  np.str_('q'): ['d8'],
#  np.str_('k'): ['e8'],
#  np.str_('p'): ['a7', 'b7', 'c7', 'd7', 'e7', 'f7', 'g7', 'h7'],
#  np.str_('P'): ['a2', 'b2', 'c2', 'd2', 'e2', 'f2', 'g2', 'h2'],
#  np.str_('R'): ['a1', 'h1'],
#  np.str_('N'): ['b1', 'g1'],
#  np.str_('B'): ['c1', 'f1'],
#  np.str_('Q'): ['d1'],
#  np.str_('K'): ['e1']}

# %%
ar_board = b.move_piece(ar_board,("Ng1","Nf3"))
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', 'N', ' ', ' '],
#        ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', ' ', 'R']], dtype='<U1')

# %%
b.last_move
# Out:
# ('Ng1', 'Nf3')

# %%
position = "e2"
position0 = ord(position[0]) - 97
position1 = 8 - int(position[1]) - 1
ar_board[position0-1][position1+1].isupper()
# Out:
# False

# %%
ar_board[position0-1][position1+1]
# Out:
# np.str_(' ')

# %%
ar_board[position0-1][position1+1]
# Out:
# np.str_(' ')
