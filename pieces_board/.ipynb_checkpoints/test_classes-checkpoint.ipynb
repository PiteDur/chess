# %%
import numpy as np
from chess import *

# %% [markdown]
# # Board

# %%
b = board("black")
ar_board = b.create_board()

# %%
b.display_board(ar_board)
# Out:
# {'a8': 'r',
#  'b8': 'n',
#  'c8': 'b',
#  'd8': 'q',
#  'e8': 'k',
#  'f8': 'b',
#  'g8': 'n',
#  'h8': 'r',
#  'a7': 'p',
#  'b7': 'p',
#  'c7': 'p',
#  'd7': 'p',
#  'e7': 'p',
#  'f7': 'p',
#  'g7': 'p',
#  'h7': 'p',
#  'a6': ' ',
#  'b6': ' ',
#  'c6': ' ',
#  'd6': ' ',
#  'e6': ' ',
#  'f6': ' ',
#  'g6': ' ',
#  'h6': ' ',
#  'a5': ' ',
#  'b5': ' ',
#  'c5': ' ',
#  'd5': ' ',
#  'e5': ' ',
#  'f5': ' ',
#  'g5': ' ',
#  'h5': ' ',
#  'a4': ' ',
#  'b4': ' ',
#  'c4': ' ',
#  'd4': ' ',
#  'e4': ' ',
#  'f4': ' ',
#  'g4': ' ',
#  'h4': ' ',
#  'a3': ' ',
#  'b3': ' ',
#  'c3': ' ',
#  'd3': ' ',
#  'e3': ' ',
#  'f3': ' ',
#  'g3': ' ',
#  'h3': ' ',
#  'a2': 'P',
#  'b2': 'P',
#  'c2': 'P',
#  'd2': 'P',
#  'e2': 'P',
#  'f2': 'P',
#  'g2': 'P',
#  'h2': 'P',
#  'a1': 'R',
#  'b1': 'N',
#  'c1': 'B',
#  'd1': 'Q',
#  'e1': 'K',
#  'f1': 'B',
#  'g1': 'N',
#  'h1': 'R'}

# %%
b.display_positions(ar_board)
# Out:
# {'r': ['a8', 'h8'],
#  'n': ['b8', 'g8'],
#  'b': ['c8', 'f8'],
#  'q': ['d8'],
#  'k': ['e8'],
#  'p': ['a7', 'b7', 'c7', 'd7', 'e7', 'f7', 'g7', 'h7'],
#  'P': ['a2', 'b2', 'c2', 'd2', 'e2', 'f2', 'g2', 'h2'],
#  'R': ['a1', 'h1'],
#  'N': ['b1', 'g1'],
#  'B': ['c1', 'f1'],
#  'Q': ['d1'],
#  'K': ['e1']}

# %%
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']], dtype='<U1')

# %%
ar_board = b.move_piece(ar_board,("Pe2","Pe4"))
ar_board
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 ar_board = b.move_piece(ar_board,("Pe2","Pe4"))
#       2 ar_board
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:118, in board.move_piece(self, actual_board, move)
#     116 rule = rules(move, self.last_move, actual_board)
#     117 if not rule.check_all():
# --> 118     raise ValueError(f"Illegal move: {rule.message}")
#     120 new_board = np.copy(actual_board)
#     121 departure = move[0][1:3]
#
# ValueError: Illegal move: Piece cannot move to the requested square.

# %%
b.last_move
# Out:
# []

# %%
b

# %%
ar_board = b.move_piece(ar_board,("Pa2","Pa4"))
ar_board = b.move_piece(ar_board,("Nb1","Nc3"))


ar_board
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 ar_board = b.move_piece(ar_board,("Pa2","Pa4"))
#       2 ar_board = b.move_piece(ar_board,("Nb1","Nc3"))
#       5 ar_board
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:114, in board.move_piece(self, actual_board, move)
#     111     raise ValueError("Move must be a tuple of (piece_and_source, destination).")
#     113 rule = rules(move, self.last_move, actual_board)
# --> 114 if not rule.check_all():
#     115     raise ValueError(f"Illegal move: {rule.message}")
#     117 new_board = np.copy(actual_board)
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:433, in rules.check_all(self)
#     432 def check_all(self):
# --> 433     if not self.check_move():
#     434         return False
#     436     new_board = self._simulate_move()
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:403, in rules.check_move(self)
#     400     self.message = "Departure square does not contain the requested piece."
#     401     return False
# --> 403 if self._same_color(self.sq_arrival):
#     404     self.message = "Arrival square is occupied by a same-color piece."
#     405     return False
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:274, in rules._same_color(self, square, board)
#     273 def _same_color(self, square, board=None):
# --> 274     piece = self._board_piece(square, board=board)
#     275     return piece != " " and piece.isupper() == self.color
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:271, in rules._board_piece(self, square, board)
#     269 def _board_piece(self, square, board=None):
#     270     board = self.board if board is None else board
# --> 271     return board[_algebraic_to_index(square)]
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:23, in _algebraic_to_index(pos)
#      17 """Convert a square like "e4" into board indices (row, col).
#      18
#      19 The board array uses row 0 for the 8th rank and row 7 for the 1st rank.
#      20 Columns go from 0 ('a') to 7 ('h').
#      21 """
#      22 col = ord(pos[0].lower()) - ord("a")
# ---> 23 row = 8 - int(pos[1])
#      24 return (row, col)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
b.last_move
# Out:
# [('Ng1', 'Nf3'), ('Pa2', 'Pa4'), ('Nb1', 'Nc3')]

# %% [markdown]
# # pieces

# %%
r1 = rook("R")
r1.possible_moves("a1",ar_board)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 r1 = rook("R")
# ----> 2 r1.possible_moves("a1",ar_board)
#
# TypeError: possible_moves() missing 1 required positional argument: 'last_move'

# %%
N1 = knight("N")
N1.possible_moves("f3",ar_board)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 N1 = knight("N")
# ----> 2 N1.possible_moves("f3",ar_board)
#
# TypeError: possible_moves() missing 1 required positional argument: 'last_move'

# %%
P2 = pawn("P")
P2.possible_moves("c2",ar_board)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 P2 = pawn("P")
# ----> 2 P2.possible_moves("c2",ar_board)
#
# TypeError: possible_moves() missing 1 required positional argument: 'last_move'

# %%
b = board("white")
ar_board = b.create_board()
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']], dtype='<U1')

# %%
lmoves = [("Pe2","Pe4"), ("pa7","pa6"), ("Pe4","Pe5"), ("pd7","pd5") ]
for tmove in lmoves : 
    ar_board = b.move_piece(ar_board,tmove)
    print(ar_board)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 lmoves = [("Pe2","Pe4"), ("pa7","pa6"), ("Pe4","Pe5"), ("pd7","pd5") ]
#       2 for tmove in lmoves :
# ----> 3     ar_board = b.move_piece(ar_board,tmove)
#       4     print(ar_board)
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:118, in board.move_piece(self, actual_board, move)
#     116 rule = rules(move, self.last_move, actual_board)
#     117 if not rule.check_all():
# --> 118     raise ValueError(f"Illegal move: {rule.message}")
#     120 new_board = np.copy(actual_board)
#     121 departure = move[0][1:3]
#
# ValueError: Illegal move: Piece cannot move to the requested square.

# %%
P5 = pawn("P")
P5.possible_moves("e2",ar_board,b.last_move)
# Out:
# ['e3', 'e4']

# %%
b.last_move
# Out:
# []
