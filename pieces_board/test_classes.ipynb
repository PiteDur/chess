# %%
import numpy as np
from chess import *

# %% [markdown]
# # Board

# %%
b = board("black")
ar_board = b.create_board()

# %%
b.display_board(ar_board)
# Out:
# {'a8': 'r',
#  'b8': 'n',
#  'c8': 'b',
#  'd8': 'q',
#  'e8': 'k',
#  'f8': 'b',
#  'g8': 'n',
#  'h8': 'r',
#  'a7': 'p',
#  'b7': 'p',
#  'c7': 'p',
#  'd7': 'p',
#  'e7': 'p',
#  'f7': 'p',
#  'g7': 'p',
#  'h7': 'p',
#  'a6': ' ',
#  'b6': ' ',
#  'c6': ' ',
#  'd6': ' ',
#  'e6': ' ',
#  'f6': ' ',
#  'g6': ' ',
#  'h6': ' ',
#  'a5': ' ',
#  'b5': ' ',
#  'c5': ' ',
#  'd5': ' ',
#  'e5': ' ',
#  'f5': ' ',
#  'g5': ' ',
#  'h5': ' ',
#  'a4': ' ',
#  'b4': ' ',
#  'c4': ' ',
#  'd4': ' ',
#  'e4': ' ',
#  'f4': ' ',
#  'g4': ' ',
#  'h4': ' ',
#  'a3': ' ',
#  'b3': ' ',
#  'c3': ' ',
#  'd3': ' ',
#  'e3': ' ',
#  'f3': ' ',
#  'g3': ' ',
#  'h3': ' ',
#  'a2': 'P',
#  'b2': 'P',
#  'c2': 'P',
#  'd2': 'P',
#  'e2': 'P',
#  'f2': 'P',
#  'g2': 'P',
#  'h2': 'P',
#  'a1': 'R',
#  'b1': 'N',
#  'c1': 'B',
#  'd1': 'Q',
#  'e1': 'K',
#  'f1': 'B',
#  'g1': 'N',
#  'h1': 'R'}

# %%
b.display_positions(ar_board)
# Out:
# {'r': ['a8', 'h8'],
#  'n': ['b8', 'g8'],
#  'b': ['c8', 'f8'],
#  'q': ['d8'],
#  'k': ['e8'],
#  'p': ['a7', 'b7', 'c7', 'd7', 'e7', 'f7', 'g7', 'h7'],
#  'P': ['a2', 'b2', 'c2', 'd2', 'e2', 'f2', 'g2', 'h2'],
#  'R': ['a1', 'h1'],
#  'N': ['b1', 'g1'],
#  'B': ['c1', 'f1'],
#  'Q': ['d1'],
#  'K': ['e1']}

# %%
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']], dtype='<U1')

# %%
ar_board = b.move_piece(ar_board,("Pe2","Pe4"))
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', 'P', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['P', 'P', 'P', 'P', ' ', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']], dtype='<U1')

# %%
b.last_move
# Out:
# [('Pe2', 'Pe4')]

# %%
b

# %%
ar_board = b.move_piece(ar_board,("Pa2","Pa4"))
ar_board = b.move_piece(ar_board,("Nb1","Nc3"))


ar_board
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 ar_board = b.move_piece(ar_board,("Pa2","Pa4"))
#       2 ar_board = b.move_piece(ar_board,("Nb1","Nc3"))
#       5 ar_board
#
# File ~\Desktop\projets_perso\chess\pieces_board\chess.py:127, in board.move_piece(self, actual_board, move)
#     125 rule = rules(move, self.last_move, actual_board)
#     126 if not rule.check_all():
# --> 127     raise ValueError(f"Illegal move: {rule.message}")
#     129 new_board = np.copy(actual_board)
#     130 origin_idx = _algebraic_to_index(departure)
#
# ValueError: Illegal move: It is not the correct player's turn.

# %%
b.last_move
# Out:
# [('Pe2', 'Pe4')]

# %% [markdown]
# # pieces

# %%
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', 'P', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['P', 'P', 'P', 'P', ' ', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']], dtype='<U1')

# %%
r1 = rook("R")
r1.possible_moves("a1",ar_board, b.last_move)
# Out:
# []

# %%
N1 = knight("N")
N1.possible_moves("f3",ar_board, b.last_move)
# Out:
# ['g5', 'e5', 'h4', 'd4']

# %%
P2 = pawn("P")
P2.possible_moves("c2",ar_board, b.last_move)
# Out:
# ['c3', 'c4']

# %%
b = board("white")
ar_board = b.create_board()
ar_board
# Out:
# array([['r', 'n', 'b', 'q', 'k', 'b', 'n', 'r'],
#        ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        ['P', 'P', 'P', 'P', 'P', 'P', 'P', 'P'],
#        ['R', 'N', 'B', 'Q', 'K', 'B', 'N', 'R']], dtype='<U1')

# %%
lmoves = [("Pe2","Pe4"), ("pa7","pa6"), ("Pe4","Pe5"), ("pd7","pd5") ]
for tmove in lmoves : 
    ar_board = b.move_piece(ar_board,tmove)
    print(ar_board)
# Out:
# [['r' 'n' 'b' 'q' 'k' 'b' 'n' 'r']
#  ['p' 'p' 'p' 'p' 'p' 'p' 'p' 'p']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' 'P' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['P' 'P' 'P' 'P' ' ' 'P' 'P' 'P']
#  ['R' 'N' 'B' 'Q' 'K' 'B' 'N' 'R']]
# [['r' 'n' 'b' 'q' 'k' 'b' 'n' 'r']
#  [' ' 'p' 'p' 'p' 'p' 'p' 'p' 'p']
#  ['p' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' 'P' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['P' 'P' 'P' 'P' ' ' 'P' 'P' 'P']
#  ['R' 'N' 'B' 'Q' 'K' 'B' 'N' 'R']]
# [['r' 'n' 'b' 'q' 'k' 'b' 'n' 'r']
#  [' ' 'p' 'p' 'p' 'p' 'p' 'p' 'p']
#  ['p' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' 'P' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['P' 'P' 'P' 'P' ' ' 'P' 'P' 'P']
#  ['R' 'N' 'B' 'Q' 'K' 'B' 'N' 'R']]
# [['r' 'n' 'b' 'q' 'k' 'b' 'n' 'r']
#  [' ' 'p' 'p' ' ' 'p' 'p' 'p' 'p']
# ...

# %%
P5 = pawn("P")
P5.possible_moves("e5",ar_board,b.last_move)
# Out:
# ['e6', 'd6']

# %%
b.last_move
# Out:
# [('Pe2', 'Pe4'), ('pa7', 'pa6'), ('Pe4', 'Pe5'), ('pd7', 'pd5')]

# %%
b = board("black")
ar_board = b.create_board(({'k': ['e8'],
     'R': ['a7', 'h1'],
     'K': ['e1']},
              "w"))
ar_board
# Out:
# array([[' ', ' ', ' ', ' ', 'k', ' ', ' ', ' '],
#        ['R', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', 'K', ' ', ' ', 'R']], dtype=object)

# %%
ar_board = b.move_piece(ar_board,("Rh1","Rh8"))
ar_board
# Out:
# array([[' ', ' ', ' ', ' ', 'k', ' ', ' ', 'R'],
#        ['R', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#        [' ', ' ', ' ', ' ', 'K', ' ', ' ', ' ']], dtype=object)
