# %% [markdown]
# Personnal tests on the chess viewer codes

# %%
import sys
import os

# %%
sys.path.append(os.path.abspath("../pieces_board"))

# %%
from chess import board
from chess_game_viewer import ChessGameViewer
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
game_board = board()
positions = {
         'P': ['e4', 'h7'],
         'p': ['e5', 'f7'],
         'K': ['e1'],
         'k': ['e8']
     }
custom_board = game_board.create_board(positions=(positions, 'w'))
viewer = ChessGameViewer(game_board)
viewer.current_board = custom_board
viewer.run()
# Out:
# Illegal move: Illegal move: Move would leave king in check.
# Illegal move: Illegal move: Move would leave king in check.
# Illegal move: Illegal move: Move would leave king in check.
# Illegal move: Illegal move: Move would leave king in check.
# Illegal move: Illegal move: Move would leave king in check.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\pipsou\anaconda3\envs\shap_env\lib\site-packages\IPython\core\interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
